# %% [markdown]
# # Requirements
#
# 1. Enable Compute Engine API https://console.cloud.google.com/marketplace/details/google/compute.googleapis.com?utm_source=codelabs&utm_medium=et&utm_campaign=CDR_sar_aiml_vertexio_&utm_content=-
#
# 2. Enable Artifact Registry API https://console.cloud.google.com/apis/library/artifactregistry.googleapis.com?utm_source=codelabs&utm_medium=et&utm_campaign=CDR_sar_aiml_vertexio_&utm_content=-
#
# 3. Enable Vertex AI API

# %%
from tensorflow.keras.datasets import mnist
from scripts.helper import preprocess_data
from trainer.task import get_model_definition

(x_train, labels_train), (x_test, labels_test) = mnist.load_data()
x_train, y_train, x_test, y_test = preprocess_data(x_train, labels_train, x_test, labels_test)

model = get_model_definition(x_train)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(
    x_train, y_train, validation_data=(x_test, y_test), epochs=20, batch_size=256
)
model.save("1_CNN.h5")
# Out:
# Epoch 1/20
# 235/235 [==============================] - 23s 96ms/step - loss: 0.3669 - accuracy: 0.8921 - val_loss: 8.7610 - val_accuracy: 0.1135
# Epoch 2/20
# 235/235 [==============================] - 22s 93ms/step - loss: 0.1105 - accuracy: 0.9653 - val_loss: 2.1878 - val_accuracy: 0.4390
# Epoch 3/20
# 235/235 [==============================] - 40s 169ms/step - loss: 0.0818 - accuracy: 0.9745 - val_loss: 0.0705 - val_accuracy: 0.9776
# Epoch 4/20
# 189/235 [=======================>......] - ETA: 3s - loss: 0.0727 - accuracy: 0.9770
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from tensorflow.keras.datasets import mnist
#       2 from scripts.helper import preprocess_data
# ----> 3 from trainer.task import get_model_definition
#       5 (x_train, labels_train), (x_test, labels_test) = mnist.load_data()
# ...
